# %%
# !pip install beir
# !pip install datasets

# %% [markdown]
# ## Partie 1

# %% [markdown]
# Fetch the DBpedia dataset

# %%
from tools.utils import download_dbpedia, download_squadv2
from src.preprocess import select_only_50words, create_dataframe_from_squad_and_dbdebia, create_unique_questions, create_question_and_answer
from src.metrics import get_ranks_for_mrr, mean_reciprocal_rank

# %%
corpus, queries, qrels = download_dbpedia()

# %%
dataset_squadv2 = download_squadv2()

# %%
words50 = select_only_50words(corpus, queries, qrels)
print(len(words50))
# Out:
# 11197

# %%
print(words50[:10])
# Out:
# [['El Asher City or Tenth of Ramadan City (Arabic: مدينة العاشر من رمضان\u200e) is a city located in Sharqia governorate in Egypt and follows the Urban Communities Authority. It is one of the cities of the first generation, and one of the largest new industrial cities, located close to the city of Cairo. It was created by Presidential Decree No.', '10th of Ramadan City', 'Which German cities have more than 250000 inhabitants?', ('10th of Ramadan City', 'El Asher City or Tenth of Ramadan City (Arabic: مدينة العاشر من رمضان\u200e) is a city located in Sharqia governorate in Egypt and follows the Urban Communities Authority. It is one of the cities of the first generation, and one of the largest new industrial cities, located close to the city of Cairo. It was created by Presidential Decree No.')], ["Abdul Hafeez Kardar (Urdu: عبد الحفیظ کاردار  \u200e) About this sound pronunciation  or Abdul Kardar (17 January 1925 – 21 April 1996) was an international cricketer, who is one of the only three players  to have played Test cricket for both India and Pakistan, the other two being Amir Elahi and Gul Mohammad. He became the first captain of the Pakistan cricket team and is widely regarded as a father figure of Pakistan's cricket.", 'Abdul Hafeez Kardar', 'Which German cities have more than 250000 inhabitants?', ('Abdul Hafeez Kardar', "Abdul Hafeez Kardar (Urdu: عبد الحفیظ کاردار  \u200e) About this sound pronunciation  or Abdul Kardar (17 January 1925 – 21 April 1996) was an international cricketer, who is one of the only three players  to have played Test cricket for both India and Pakistan, the other two being Amir Elahi and Gul Mohammad. He became the first captain of the Pakistan cricket team and is widely regarded as a father figure of Pakistan's cricket.")], ['Afragola [afraˈɡoːla] (Neapolitan: Afravóla; Afragolese dialect: Afraóra) is a city and comune in the Metropolitan City of Naples, southern Italy. It is one of the 100 largest Italian cities (the ones that have a population of more than 63,000 inhabitants).The communal territory, measuring 18 square kilometres (7 square miles), borders  the municipalities of Acerra, Casalnuovo di Napoli, Caivano, Cardito and Casoria, forming a single metropolitan area of around 100,000 inhabitants.', 'Afragola', 'Which German cities have more than 250000 inhabitants?', ('Afragola', 'Afragola [afraˈɡoːla] (Neapolitan: Afravóla; Afragolese dialect: Afraóra) is a city and comune in the Metropolitan City of Naples, southern Italy. It is one of the 100 largest Italian cities (the ones that have a population of more than 63,000 inhabitants).The communal territory, measuring 18 square kilometres (7 square miles), borders  the municipalities of Acerra, Casalnuovo di Napoli, Caivano, Cardito and Casoria, forming a single metropolitan area of around 100,000 inhabitants.')], ["Al-Qa'im (القائم) is an Iraqi town located nearly 400 km northwest of Baghdad near the Syrian border and situated along the Euphrates River, and located in the Al Anbar Governorate. It has a population of about 250,000 and is the center of the Al-Qa'im District.The Al-Qa'im region has some of the richest soil in the Middle East.", "Al-Qa'im (town)", 'Which German cities have more than 250000 inhabitants?', ("Al-Qa'im (town)", "Al-Qa'im (القائم) is an Iraqi town located nearly 400 km northwest of Baghdad near the Syrian border and situated along the Euphrates River, and located in the Al Anbar Governorate. It has a population of about 250,000 and is the center of the Al-Qa'im District.The Al-Qa'im region has some of the richest soil in the Middle East.")], ["Albert Edwin Trott (6 February 1873 – 30 July 1914) was a Test cricketer for both Australia and England. He was named as one of the Wisden Cricketers of the Year in 1899. He is believed to be the only batsman to have struck a ball over the top of the Lord's Pavilion.  He is also one of only two players to take two hat-tricks in the same first-class innings, the other being ...

# %%
df, questions_list, contexts, titles, answers = create_dataframe_from_squad_and_dbdebia(dataset_squadv2, words50)
df
# Out:
#                                                 question  ...                                            answers
# 0                   In what country is Normandy located?  ...  {'text': ['France', 'France', 'France', 'Franc...
# 1            Who was the duke in the battle of Hastings?  ...  {'text': ['William the Conqueror', 'William th...
# 2       What is the original meaning of the word Norman?  ...  {'text': ['Viking', 'Norseman, Viking', 'Norse...
# 3                When was the Duchy of Normandy founded?  ...  {'text': ['911', '911', '911'], 'answer_start'...
# 4      Who upon arriving gave the original viking set...  ...  {'text': ['Rollo', 'Rollo', 'Rollo'], 'answer_...
# ...                                                  ...  ...                                                ...
# 11795                                                     ...
# 11796                                                     ...
# 11797                                                     ...
# 11798                                                     ...
# 11799                                                     ...
#
# [11800 rows x 4 columns]

# %%
uniques_question = create_unique_questions(questions_list)
uniques_question[:10]
# Out:
# ['In what country is Normandy located?',
#  'Who was the duke in the battle of Hastings?',
#  'What is the original meaning of the word Norman?',
#  'When was the Duchy of Normandy founded?',
#  'Who upon arriving gave the original viking settlers a common identity?',
#  'What was the Norman religion?',
#  "What was one of the Norman's major exports?",
#  "Who was the Normans' main enemy in Italy, the Byzantine Empire and Armenia?",
#  'When did Herve serve as a Byzantine general?',
#  'What was the name of the Norman castle?']

# %%
question_and_answer = create_question_and_answer(df, uniques_question)
question_and_answer
# Out:
# {'In what country is Normandy located?': [0],
#  'Who was the duke in the battle of Hastings?': [1],
#  'What is the original meaning of the word Norman?': [2],
#  'When was the Duchy of Normandy founded?': [3],
#  'Who upon arriving gave the original viking settlers a common identity?': [4],
#  'What was the Norman religion?': [5],
#  "What was one of the Norman's major exports?": [6],
#  "Who was the Normans' main enemy in Italy, the Byzantine Empire and Armenia?": [7],
#  'When did Herve serve as a Byzantine general?': [8],
#  'What was the name of the Norman castle?': [9],
#  'What were the origins of the Raouliii family?': [10],
#  'What was the name of the count of Apulia ': [11],
#  'Where did the Normans and Byzantines sign the peace treaty?': [12],
#  'When did the Normans attack Dyrrachium?': [13],
#  'Who did Emma Marry?': [14],
#  "Who was Edward the Confessor's half-brother?": [15],
#  'Where did Harold II die?': [16],
#  "What was the Anglo-Norman language's final form?": [17],
#  "In what year did the Norman's invade at Bannow Bay?": [18],
#  "Who was Margaret's brother?": [19],
#  'Who did Alexander I marry?': [20],
#  'Where was Ralph earl of?': [21],
#  'What country was under the control of Norman barons?': [22],
#  'What year did Roger de Tosny fail to accomplish what he set out to do?': [23],
#  'When did the Siege of Antioch take place?': [24],
#  'How long did Western Europe control Cyprus?': [25],
#  "What ruined Richard's plans to reach Acre?": [26],
#  "Who was Guy's Rival?": [27],
#  'What continent are the Canarian Islands off the coast of?': [28],
#  'Who became the King of the Canary Islands?': [29],
#  'Where are Jersey and Guernsey': [30],
#  'What is the Norman architecture idiom?': [31],
#  'What architecture type came after Norman in England?': [32],
#  'When did the church reform begin?': [33],
#  'When were the French wars of religion?': [34],
#  'What kind of needlework was used in the creation of the Bayeux Tapestry?': [35],
#  'What is the most important type of Norman art preserved in churches?': [36],
#  'In what century did important classical music developments occur in Normandy?': [37],
#  'Where did the monks flee to?': [38],
#  'What branch of theoretical computer science deals with broadly classifying computational problems by difficulty and class of relationship?': [39],
#  'What measure of a computational problem broadly defines the inherent difficulty of the solution?': [40],
#  'What two fields of theoretical computer science closely mirror computational complexity theory?': [41],
#  'What is the name given to the input string of a computational problem?': [42],
#  'By how many kilometers does the traveling salesman problem seek to classify a route between the 15 largest cities in Germany?': [43],
#  'In a computational problem, what can be described as a string over an alphabet?': [44],
#  'What kind of problems are one of the main topics studied in computational complexity theory?': [45],
#  'What kind of graph is an example of an input used in a decision problem?': [46],
#  'A function problem is an example of what?': [47],
#  'How can function problems typically be restated?': [48],
#  'What is a commonly used measurement used to determine the complexity of a computational problem?': [49],
#  'Whose thesis states that the solution to a problem is solvable with reasonable resources assuming it allows for a polynomial time algorithm?': [50],
#  'What is the term for a mathematical model that theoretically represents a general computing machine?': [51],
#  'What is generally considered to be the most basic iteration of a Turing machine?': [52],
#  'Turing machines are commonly employed to define what? ': [53],
#  'What is an example of a machine model that deviates from a generally accepted multi-tape Turing machine?': [54],
#  'What type of Turing machine can be characterized by checking multiple possibilities at the same time?': [55],
#  'The time required to output an answer on a deterministic Turing machine is expressed as what?': [56],
#  'Time and space are both examples of what type of resource?': [57],
#  'What are the three primary expressions used to represent case complexity?': [58],
#  'What provides a solution to a list of integers provided as input that ned to be sorted?': [59],
#  'Classification of resources is contingent on determining the upper and lower bounds of minimum time required by what?  ': [60],
#  'What expression is generally used to convey upper or lower bounds?': [61],
#  'What has complicated definitions that prevent classification into a framework?': [62],
#  'Concrete bounding of computation time frequently produces complexity classes contingent upon what?': [63],
#  'What are two examples of measurements are bound within algorithms to establish complexity classes?': [64],
#  'What are three examples of complexity classes associated with definitions established by probabilistic Turing machines?': [65],
#  'What is an example of a measurement within a complexity class that would create a bigger set of problems if the bounds were relaxed?': [66],
#  'What is the foundation for separation results within complexity classes?': [67],
#  'What concept is frequently used to define complexity classes?': [68],
#  'What is the most frequently employed type of reduction?': [69],
#  'The complexity of problems often depends on what?': [70],
#  'The hardest problems in NP can be analogously written as what class of problems?': [71],
#  'What complexity class is characterized by a computational tasks and efficient algorithms?': [72],
#  'If P is ultimately proven to be equal tot NP, what effect would this have on the efficiency of problems?': [73],
#  'Who demonstrated that P= NP implies problems not present in P or NP-complete?': [74],
#  'What is the problem attributed to defining if two finite graphs are isomorphic?': [75],
#  'What computational problem is commonly associated with prime factorization?': [76],
#  'What is the unproven assumption generally ascribed to the value of complexity classes?': [77],
#  'In what complexity class do complement problems of NP problems exist?': [78],
#  'What variable is associated with all problems solved within logarithmic space?': [79],
#  'Problems capable of theoretical solutions but consuming unreasonable time in practical application are known as what?': [80],
#  'What eponymous variation of arithmetic presents a decision problem not evidenced in P?': [81],
#  'What tactic did researchers employ to offset the former deficit of work surrounding the complexity of algorithmic problems?': [82],
#  'What paper is commonly considered the bellwether ushering in systematic studies computational complexity?': [83],
#  'Who provided a definition of linear bounded automata in 1960?': [84],
#  'What is the concrete choice typically assumed by most complexity-theoretic theorems?': [85],
#  'Who is responsible for axiomatic complexity theory?': [86],
#  'What is Southern California often abbreviated as?': [87],
#  'What is the name of the region that is not defined by the eight or 10 county definitions?': [88],
#  'Which coastline does Southern California touch?': [89],
#  'What is the name of the water body that is found to the east?': [90],
#  'The cities of Los Angeles and San Diego are a part of which state?': [91],
#  'Orange, San Diego, Riverside and San Bernardino make up four of the five counties. What is the name of the last county?': [92],
#  'What is the name given to the district that is associated with the motion picture industry?': [93],
#  'Other than surf, what other culture is southern California home to?': [94],
#  'What is the name of the desert city?': [95],
#  "Geographically speaking, where is California's north - south midway point in terms of latitude?": [96],
#  'Which country used to rule California?': [97],
#  'Other than land laws, what else were the Californios dissatisfied with?': [98],
#  'Which newspaper defined southern California?': [99],
#  'Which organizations most commonly divide and promote the state?': [100],
#  "Where does southern California's megalopolis standard in terms of population nationwide?": [101],
#  'What is the main gap to continued urbanization?': [102],
#  'What kind of climate does southern California maintain?': [103],
#  "What term best describes southern California's collection of landscapes?": [104],
#  'How many earthquakes does southern California experience in a year?': [105],
#  'Which fault can produce a magnitude earthquake of 8.0?': [106],
#  "Southern California's distinctive regions are divided culturally, politically and what other trait?": [107],
#  'Southern California had a population of 22,680,010 according to the census from which year?': [108],
#  'What is the name associated with the eight areas that make up a part of southern California?': [109],
#  'What is the largest city in all of California?': [110],
#  'What resource is the economy of southern California depedent on?': [111],
#  'Motion pictures, petroleum and aircraft manufacturing have been major industries since which decade?': [112],
#  'What type of district is southern California home to many of?': [113],
#  'Downtown Burbank is an example of what kind of district?': [114],
#  'The Sand Bernardino - Riverside area maintains what kind of district?': [115],
#  'Which county is developing its business center?': [116],
#  'What is the central business district of San Diego?': [117],
#  'What is the second busiest airport in the United States?': [118],
#  'What is the name of the commuter rail system?': [119],
#  'What is the United States busiest commercial port?': [120],
#  "What is the moniker that is being used to describe the region's diversified technology?": [121],
#  'The Los Angeles Rams are an example of what kind of sports team?': [122],
#  'Which team was suspended from the MLS?': [123],
#  'What other kind of sport is popular in southern California?': [124],
#  'What is a growing sport in southern California?': [125],
#  'What company was formed by the merger of Sky Television and British Satellite Broadcasting?': [126],
#  'What year was Setanta Sports awarded Primeier Leage rights to broadcast?': [127],
#  'What consortium was BSkyB excluded from?': [128],
#  'What service did BSkyB chare additional subscription fees for?': [129],
#  'What is the name of the TV scrambling system BSkyB uses?': [130],
#  'What year did BSkyB and Virgin Media have a dispute over the carriage of Sky Channels on cable TV?': [131],
#  'when did the English High court find Microsoft\'s use of the term "SkyDrive" infringed on Sky\'s right?': [132],
#  'Who was the chief executive officer when the service began?': [133],
#  'Sky UK Limited is formerly known by what name?': [134],
#  "What is the name of Sky Q's broadband router?": [135],
#  "What are BSkyB's standard definition broadcasts compliant with?": [136],
#  'When was Sky Digital launched?': [137],
#  "When did BSkyB launch it's HDTV service?": [138],
#  "When did BSkyB announce it's intention to replace it's free-to-air digital channels?": [139],
#  'What are free-to-air encrypted broadcasts known as?': [140],
#  'When were the talks held for braodcast right to the Primier league for a five year period from the 1992 season?': [141],
#  'Who does BSkyB have an operating license from?': [142],
#  "When was BSkyB's digital service launched?": [143],
#  'When was virgin media rebranded from NTL Telewest?': [144],
#  "How many homes had BSkyB's direct-to-home satellite service available to them in 2010?": [145],
#  'What did Alec Shelbrooke propose payments of benefits to be made on?': [146],
#  'What were the annual carriage fees for the channels?': [147],
#  'What kind of economy does Victoria have?': [148],
#  'Where is the Asian influence strongest in Victoria?': [149],
#  'What kind of representational system does the Victorian Legislative Council have?': [150],
#  "What political party is strongest in Melbourne's working class suburbs?": [151],
#  'What percentage of Victorians are Christian?': [152],
#  'Where in Australia is Victoria located?': [153],
#  'What is the term for the original Aboriginal people of Victoria?': [154],
#  'How much Victorian farmland is farmed in grains?': [155],
#  'When did Victoria enact its constitution?': [156],
#  'What is the weather type of Mallee and upper Wimmera?': [157],
#  'What are public schools in Victoria?': [158],
#  'What type of manufacturing plant is Victoria soon losing?': [159],
#  "How high are Victoria's alpine regions?": [160],
#  'Where is the coldest section of Victoria?': [161],
#  'Who owns the rail lines in Victoria?': [162],
#  'How many seats does Victoria have in the Australian House of Representatives?': [163],
#  'On what date was Victoria declared independent from New South Wales?': [164],
#  'By August 2010 how many public schools did Victoria have?': [165],
#  'What state in Australia is the center of dairy farming?': [166],
#  'What is the gauge of the Victorian rail lines?': [167],
#  'When was the colony of New South Wales founded?': [168],
#  'When was there a armed protest at Ballarat about mining taxes?': [169],
#  'What does the Premier of Victoria need to lead in the Legislative Assembly? ': [170],
#  'How much did the gross agricultural product increase from 2003-04?': [171],
#  "What part do events in Victoria's economy  play? ": [172],
#  "Where was France's Huguenot population largely centered?": [173],
#  'The term Huguenot was originally meant to confer?': [174],
#  'What helped spread Protestantism in France?': [175],
#  'What were the towns granted to the Huguenots in 1598 collectively called?': [176],
#  'Where did the first Huguenot colonists settle?': [177],
#  'When did Huguenots colonize in North America?': [178],
#  'What southern city did the Huguenots settle near?': [179],
#  "Who was Louis XIV's main rival?": [180],
#  'What proclamation abolished protestantism in France?': [181],
#  'What group specifically opposed the Huguenots?': [182],
#  'What were the civil wars caused by the Huguenots called?': [183],
#  'How many protestants live in France today?': [184],
#  'What city north of New York was settled by Huguenots?': [185],
#  'What country initially received the largest number of Huguenot refugees?': [186],
#  'Where was the Gate of King Hugo?': [187],
#  'Where did Huguenots and Walloons settle in England?': [188],
#  'What Irish cities had Huguenot mayors in the 1600s and 1700s?': [189],
#  'What is the common term for the loss of key members of French society to Huguenot emigration?': [190],
#  'What was Henry IV known as before taking the throne?': [191],
#  'What was required of Huguenot children after the Edict was revoked?': [192],
#  'What were the first two destinations of Huguenot emigres?': [193],
#  'Families with French names in South Africa speak what language today?': [194],
#  'What Revolutionary War midnight rider was a Huguenot descendant?': [195],
#  'What industry was centered in Bedfordshire?': [196],
#  'What were the two Huguenot neighborhoods created in Berlin?': [197],
#  'Which central European country had a Calvinist ruler?': [198],
#  'There was a 16th century Huguenot settlement near what modern day Florida city?': [199],
#  'What was the name of the first Huguenot outpost in South Carolina?': [200],
#  'In what English colony were Huguenot settlers promised land?': [201],
#  'When was the Dutch Revolt?': [202],
#  'What English law made that country more welcoming to Huguenots?': [203],
#  'What war in Ireland featured Huguenot regiments?': [204],
#  'Which noble helped establish the Huguenot settlement in Saarland?': [205],
#  'What two member nations of the Holy Roman Empire received Huguenot refugees?': [206],
#  'From what French King did the Huguenot name possibly descend?': [207],
#  'Who was one French pro-reform Roman Catholic of the 15th century? ': [208],
#  "When was the St. Bartholomew's Day Massacre?": [209],
#  'Who became king in 1643?': [210],
#  'What present day county is New Rochelle in?': [211],
#  'How did Huguenots evolve their religious beliefs in the New World?': [212],
#  'Who was a prominent Huguenot in Holland?': [213],
#  'What early Huguenot Church was established in England?': [214],
#  'What protestant religions made Northern European counties safe for Huguenot immigration?': [215],
#  'What German ruler invited Huguenot immigration?': [216],
#  'Along with geothermal and nuclear, what is a notable non-combustion heat source?': [217],
#  'What was the first true engine that was commercially successful?': [218],
#  'In what country was a full-scale working railway steam locomotive first invented?': [219],
#  'What device is used to recycle the boiler water in most steam engines?': [220],
#  'How many expansion stages are used by the triple expansion engine?': [221],
#  'Along with poppet valve gears, what type of gears utilized separate admission and exhaust valves to give ideal events?': [222],
#  "What are sometimes present in the boiler's firebox crown?": [223],
#  'Who patented a steam engine in 1781?': [224],
#  'In what century did the history of the steam engine begin?': [225],
#  'What type of engines became widespread around the end of the 19th century?': [226],
#  'The use of what device represented the last major evolution of the steam engine?': [227],
#  'What is the usual source of heat for boiling water in the steam engine?': [228],
#  'What instrument is used to examine steam engine performance?': [229],
#  'At what degree are the pistons of a two-cylinder compound connected to the cranks?': [230],
#  'What is a term for the reversing of steam flow in a piston engine after each stroke?': [231],
#  'What is the name of a uniflow engine that takes in steam in hot areas and exhausts it in cold?': [232],
#  "What type of steam engine doesn't need valves to direct steam?": [233],
#  'What happens to the working fluid in a closed loop system?': [234],
#  "What limits the Rankine cycle's efficiency?": [235],
#  'What devices have been credited as the moving force of the Industrial Revolution?': [236],
#  'What was the name of the locomotive that debuted in 1808?': [237],
#  'Who patented a high-pressure compound engine in 1805?': [238],
#  'What percentage of electricity was made by steam turbine in the 1990s?': [239],
#  "What is the steam engine's thermodynamic basis?": [240],
#  'How was the efficiency of a steam engine typically evaluated?': [241],
#  'What type of engines became popular for power generation after piston steam engines?': [242],
#  'Who developed the first commercial steam powered device?': [243],
#  'Who invented a high-pressure steam engine around 1800?': [244],
#  'What modern company has been notably working on a steam engine using modern materials?': [245],
#  'What do power station steam turbines use as a cold sink in the absence of CHP?': [246],
#  'What did Watt add to the steam engine in 1788?': [247],
#  'After what year was compounding frequently used in marine engines?': [248],
#  'What is another term for shortening the admission event?': [249],
#  'Who received the first steam engine patent?': [250],
#  'What is another term for rotors?': [251],
#  'What is the power-to-weight ratio of a steam plant compared to that of an internal combustion engine?': [252],
#  'What is an example of a rotary engine without pistons?': [253],
#  "When did Watt finish the development of his improvements to Newcomen's engine?": [254],
#  'How many mechanisms does a typical steam engine have to keep boiler pressure from getting too high?': [255],
#  'What was the ultimate development of the horizontal engine?': [256],
#  "What scientific field's theory has received contributions from the steam engine?": [257],
#  'What is a main advantage of the Rankine cycle?': [258],
#  'What is an example of a pump component?': [259],
#  'The frequent availability of what substance allowed land-based steam engines to exhaust a great deal of steam?': [260],
#  'What do nuclear power plants heat to create electricity?': [261],
#  'What is the Rankine cycle sometimes called?': [262],
#  'The atomic number of the periodic table for oxygen?': [263],
#  'Oxygen is released in cellular respiration by?': [264],
#  'Who proved that air is necessary for combustion?': [265],
#  '"An Account of Further Discoveries in Air" was published by who in 1775?': [266],
#  'What inventor built on to the findings of Philo of  Byzantium?': [267],
#  'What is needed to make combustion happen?': [268],
#  '______ In both liquid and gas form can fastly result in an exlposion.': [269],
#  "Silicates of magnesium and iron make up of the Earth's ___": [270],
#  'What did John Dalton think that all elements were in number present in compounds?': [271],
#  'Of what were materials that left little residue thought to contain?': [272],
#  'How is dioxygen most simply described?': [273],
#  'When did Carl Wilhelm Scheele discover oxygen?': [274],
#  'What is the term for the arrangement of two unpaired electrons in dioxygen?': [275],
#  'What did Lavoisier conclude was consumed by combustion in his experiments?': [276],
#  'What is the name for O3 most often used?': [277],
#  'What is the most common form of oxygen on the planet?': [278],
#  'What chemist managed to make enough liquid oxygen to use for study?': [279],
#  'What component of water is more soluble than nitrogen?': [280],
#  "Where does oxygen rank by mass in the planet's biosphere?": [281],
#  'By what century did researchers see that they could liquefy air?': [282],
#  'What celestial object eluded efforts to measure oxygen?': [283],
#  'What is the name for a form of oxygen in which electrons are paired?': [284],
#  'What group of scientists seek to measure the amounts of oxygen in marine animals?': [285],
#  'At what wavelength do the spectrophotometric bands peak?': [286],
#  'What magnetic character do triplet O2 have?': [287],
#  'What do the reactive forms of oxygen produce in organisms?': [288],
#  'At what temperature will oxygen condense?': [289],
#  'Where on Earth is free oxygen found?': [290],
#  'When did photosynthetic organisms evolve on Earth?': [291],
#  'What produces the high levels of oxygen on Earth?': [292],
#  'What mechanism can be used to make oxygen?': [293],
#  'Electrolysis of what can be used to produce oxygen and hydrogen?': [294],
#  'As a euphoric how is oxygen used in bars?': [295],
#  'What device is used to treat various conditions such as carbon monoxide poisoning?': [296],
#  'In what process is the uptake from oxygen necessary?': [297],
#  'What characteristic of oxygen causes it to form bonds with other elements?': [298],
#  'What event would necessitate airline passengers to need a supplemental supply of oxygen? ': [299],
#  'What do oxygen tanks, cryogenics, and chemical compounds serve as for oxygen?': [300],
#  'What type of compounds such as acetone,contain oxygen?': [301],
#  'In what type of molecules are oxygen found?': [302],
#  'What health condition can deep sea diving cause?': [303],
#  'Why is breathing oxygen in space craft not dangerous to health?': [304],
#  'When can oxygen gas produce a toxic condition?': [305],
#  'When did the 1973 oil crisis begin?': [306],
#  'Why did the European nations and Japan separated themselves from United States during the crisis?': [307],
#  'When did the United States withdraw from the Bretton Woods Accord?': [308],
#  'From 1947 to 1967, how much did the price of oil increase?': [309],
#  'When did Syria and Egypt launch a surprise attack on Israel?': [310],
#  'Why did OPEC raise the price of oil to $5.11?': [311],
#  'How much did Saudi Arabia spend on spreading Wahhabism?': [312],
#  'What is one of the reason that US production has been held responsible for recessions and lower economic growth?': [313],
#  'What has a negative influence over the US economy?': [314],
#  'Which country faced a complete embargo in the EEC?': [315],
#  'Which country is not badly hit by the embargo?': [316],
#  'What made the oil crisis worse in the US?': [317],
#  'Who is the first administrator of the Federal Energy Office?': [318],
#  'What is the speed limit set to reduce consumption?': [319],
#  'What was the catalyst that created greater interest in renewable resources?': [320],
#  'Which country was thinking about going to war to forcibly take Middle Eastern oil fields?': [321],
#  'Which country is the most dependent on Arab oil?': [322],
#  "Which country's invasion show the insecurity of the Middle East?": [323],
#  'Which sized cars were the least demanded cars in the crisis?': [324],
#  'When did Honda, Toyota and Nissan open US assembly plants?': [325],
#  'Name a type of Toyota compact trucks?': [326],
#  'Why did GM, Ford and Chrysler introduced fuel-efficient and small cars to the US market?': [327],
#  'By which year did full sized American cars shrink to be smaller?': [328],
#  'When was OPEC production of oil being surpassed?': [329],
#  'What is European Union Law?': [330],
#  'Who applies European Union law?': [331],
#  'What are the two primary constitutional sources of the European Union?': [332],
#  'Which treaty provides that the European Union law be applied to metropolitan territories of member states?': [333],
#  'How did the principle treaties that form the European Union begin?': [334],
#  'When was there an attempt to reform the law of the EU?': [335],
#  'What is the main executive body of the EU?': [336],
#  'What commission was censured in 1999, and paved the way for Commissioners to abuse their power?': [337],
#  'The legislative body, the Council, are made up of what type of individuals?': [338],
#  "What type of vote must the Parliament have to either block or suggest changes to the Commission's proposals?": [339],
#  'Which branch of the EU has had the most influence on the development of EU law?': [340],
#  'If there is a conflict between EU law and national law, which law take precedence?': [341],
#  'What do all member states agree takes precedence over national law?': [342],
#  'Which type of law makes EU institutions and its member states follow the law?': [343],
#  "In which case was it held that the provisions of the treaties are directly effective if they are clear, unconditional, and don't require further action by EU or national authorities?": [344],
#  'What generally does not allow citizens to sue other citizens?': [345],
#  "What happens first if a Directive's deadline for implementation is not met?": [346],
#  'Which courts have a duty to interpret domestic law as far as possible?': [347],
#  'Which entity developed the principles of European Union Law?': [348],
#  'How long has Proportionality been recognized as one of the general principles of EU law?': [349],
#  'How long has the concept of legal certainty been recognized as one of the general principles by the EU law?': [350],
#  'Where is the European Court of justice likely to get inspiration from?': [351],
#  'How many original treaties establishing the EU protected fundamental rights?': [352],
#  'When was the Lisbon Treaty established?': [353],
#  'The Social Chapter is a chapter of what treaty?': [354],
#  'How many member states adopted the Social Charter in 1989?': [355],
#  'What lead to the UK to subscribe to the agreement on Social Policy?': [356],
#  'Which countries were the European Coal and Steel Community agreement between?': [357],
#  'In which article does the Treaty of Lisbon prohibit anti-competitive agreements?': [358],
#  'When was the concept of a social market economy introduced into EU law?': [359],
#  'What helps the process of free movement of goods?': [360],
#  'What is the minimum percent of alcohol content a German law requires all spirits and liqueurs to have?': [361],
#  'Which two importers claimed that under a French competition law, they were prevented from selling Picon beer under wholesale price?': [362],
#  'What have the Treaties sought to enable since its foundation?': [363],
#  'Which articles of the Free Movement of Workers Regulation set out the primary provisions on equal treatment of workers?': [364],
#  'What has lately been being viewed as a fundamental status of member state nationals by the Court of Justice?': [365],
#  'Which Treaty protects the freedom of establishment and the freedom to provide services?': [366],
#  'In which year did a toxic waste spill from a European ship prompt the Commission to look into legislation against waste?': [367],
#  'The freedom to provide services under TFEU article 56 applies to who?': [368],
#  "Which newspaper's parent company could not evade tax by shifting its residence to the Netherlands?": [369],
#  'Which name is also used to describe the Amazon rainforest in English?': [370],
#  'Which type of climate may have allowed the rainforest to spread across the continent?': [371],
#  'In which point did the drainage basin of the Amazon split?': [372],
#  'What does LGM stands for?': [373],
#  'What is the name of the satellite that measured the amount of dust?': [374],
#  'What is the name of the book written by Archeologist Betty Meggers?': [375],
#  'Who was the first European to travel the Amazon River?': [376],
#  'What is terra preta called?': [377],
#  'How many species of insects are known in the region?': [378],
#  'How many kilometers of acres of the Ecuadorian rainforest is supported?': [379],
#  'Which animal that lives in the Amazon river may produce a deadly shock?': [380],
#  'What is the process of removing trees from a forest known as?': [381],
#  'How many square kilometres of the Amazon forest was lost by 1991?': [382],
#  'Highways built in the Amazon rainforest were built primarily for what kind of farmers?': [383],
#  'What are environmentalists concerned about losing in the Amazon forest?': [384],
#  'What change in conditions may make the Amazon rainforest unsustainable?': [385],
#  'What kind of territories are being destroyed by ecocide in the Amazon?': [386],
#  'What kind of sending technology is being used to protect tribal lands in the Amazon?': [387],
#  'Classifying the stages of what is important to mapping aspects of the Amazon?': [388],
#  'In what year did the Amazon experience its worst drought of recent history?': [389],
#  'In what year did the Amazon experience a drought that may have been more extreme than in 2005?': [390],
#  'What is a ctenophora?': [391],
#  'How many species of Ctenophora have been validated?': [392],
#  'What is unique about  a hermaphrodite?': [393],
#  'What does the Beroe eat? ': [394],
#  'When did the Cretaceous-Paleogene extinction happen?': [395],
#  'Jellyfish ans sea anemones belong to what phylum?': [396],
#  'What is the jelly-like susbtance called?': [397],
#  'What are the hairs on ctenophores called?': [398],
#  'Which cidippid is used as a description on ctenophores in most textbooks?': [399],
#  'The inside of a ctenophore is lined with what?': [400],
#  'What are the eight comb rows on the outer surface called?': [401],
#  'How do ctenophores control buoyancy?': [402],
#  'What is the largest sensory feature of the ctenophora?': [403],
#  'What is the common coastal pleurobrachia called?': [404],
#  'What are the tentacles of cydipped ctenophores are usually fringed with?': [405],
#  'How many rows of combs are there?': [406],
#  'What does the lobata have pair of?': [407],
#  'What does the bathocyroe and ocyropsis do to escape danger?': [408],
#  'Beroida are known by what other name?': [409],
#  'Which species are ribbon-shaped planktonic animals?': [410],
#  'What do most platyctenida have on their aboral surface?': [411],
#  'How are eggs and sperm released?': [412],
#  'Juvenile and adult  beroe lack what?': [413],
#  'What do bathyctena chuni, euplokamis stationis and eurhamphaea vexilligera have in common?': [414],
#  'Are ctenophores predators, vegetarian or parasitic?': [415],
#  'Why was it thought that  ctenophores were a poor diet for other animals?': [416],
#  'What is blamed for causing the sharp drop in fish catches in the Black Sea and the Sea of Azov?': [417],
#  'Why are ctenophores extremely rare as fossils?': [418],
#  'How old were the fossils found in China?': [419],
#  'Recent studies believe  that ctenophores are the sister lineage to what?': [420],
#  'Which genus of ctenophores does not have cydipped-like larvae?': [421],
#  'Which city is the fifth-largest city in California?': [422],
#  'The Central Pacific Railroad established a station for its new line in what year?': [423],
#  'In 1940, what percentage of the population in Fresno was Asian?': [424],
#  'What new product did Bank of America introduce in 1958?': [425],
#  'Who wrote "Walking in Fresno?"': [426],
#  'How many large public parks does Fresno have?': [427],
#  'During what period did downtown Fresno thrive?': [428],
#  'In what year did Fresno get its first pedestrian mall?': [429],
#  'Where is the neighborhood of Sunnyside located in Fresno?': [430],
#  'The Tower District is centered around which historic theatre?': [431],
#  'During what period did the Tower Theatre re-open?': [432],
#  'What type of theater do the neighborhoods feature?': [433],
#  'What type of homes is Fresno known for?': [434],
#  'Which boulevard can you find many majestic homes in the area?': [435],
#  'What is another name for the west side of Fresno?': [436],
#  'Who is Kearney Boulevard named after?': [437],
#  'When were the public housing developments built in the neighborhood?': [438],
#  'Who founded Woodward Park?': [439],
#  'When was the Sierra Sky Park Airport formed?': [440],
#  'How would one describe the summers in Fresno?': [441],
#  'What is the hottest temperature record for Fresno?': [442],
#  "what was Fresno's population in 2010?": [443],
#  'How many households has kids under the age of 18 living in them?': [444],
#  'How many people lived in Fresno in 2000, according to the Census Bureau? ': [445],
#  'Why does Fresno only have UHF television stations?': [446],
#  'What route connects Fresno with the California Central Valley?': [447],
#  'Which is the largest city not connected to an interstate highway?': [448],
#  'Which company provides train service in Fresno?': [449],
#  'What did Paul Baran develop ': [450],
#  'Packet Switching contrast with what other principal ': [451],
#  'In cases of shared physical medium how are they delivered ': [452],
#  'What did Baran develop during research at RAND ': [453],
#  'What did Donald Davies Develop': [454],
#  'What does each packet includ in connectionless mode ': [455],
#  'What does connection orientation require': [456],
#  'WHat do x.25 and Frame Relay both require': [457],
#  'WHen did ARPNET and SITA become operational': [458],
#  'What was Apple Talk ': [459],
#  'What network was designed by the french ': [460],
#  'What is  DECnet': [461],
#  'What was Warner Sinback': [462],
#  'WHy was the Merit network formed in Michigan ': [463],
#  'What was telenet ': [464],
#  'What was Tymnet': [465],
#  'How many types of X.25 networks were there originally ': [466],
#  'What was AUSTPAC': [467],
#  'What was DATANET 1 ': [468],
#  'What is CSNET': [469],
#  ' what is Internet2': [470],
#  'What is NSFNET': [471],
#  'what does vBNS stand for ': [472],
#  'Where did the black death originate?': [473],
#  'What does it mean for a disease to be enzootic?': [474],
#  'Who introduced plague to Europe?': [475],
#  'Which direction did the disease first move in?': [476],
#  'What effect did the plague have on the Middle East?': [477],
#  'Who claimed that the name Black Death first appeared in 1631?': [478],
#  'What was the black death originally blamed on?': [479],
#  'What was considered responsible for the black death as well as the epidemic in southern China?': [480],
#  'Who wrote about the great pestilence in 1893?': [481],
#  'What is the mortality rate of the modern bubonic plague?': [482],
#  'When did the Plos Pathogens paper come out?': [483],
#  'What are clades?': [484],
#  'What is the current status of the Haensch study?': [485],
#  'Who challenged the plague theory first?': [486],
#  'What is as important as identifying plague symptoms?': [487],
#  'Why might rats not be responsible for the plague?': [488],
#  'What does Graham Twigg propose about the spread of disease?': [489],
#  'How much of the population in the Middle East died of the plague?': [490],
#  'When did the plague return to Europe?': [491],
#  'What did historians do in the absence of census figures?': [492],
#  'How many people died of plague in Paris in 1466?': [493],
#  'How many were killed by plague in Italy in the 17th century?': [494],
#  'During which years was the plague present in Islamic countries?': [495],
#  'An igneous rock is a rock that crystallizes from what?': [496],
#  "What was the most important discovery that led to the understanding that Earth's lithosphere is separated into tectonic plates?": [497],
#  'What is the area called where two plates move apart?': [498],
#  'What types of waves do seismologists use to image the interior of the Earth?': [499],
#  'Why is the second timeline needed? ': [500],
#  'What principle relates to the formation of faults and the age of the sequences through which they cut? ': [501],
#  'What foreign bodies, which are older than the rocks themselves, occur igneous rocks?': [502],
#  'Which principle is based on the appearance of fossils in sedimentary rocks?': [503],
#  'When was the ability to use radioactive isotopes to date rock formations developed?': [504],
#  'What techniques can be used to determine paleotopography?': [505],
#  'Rock units become thicker and shorten when placed under this type of compression. ': [506],
#  'This causes the rock unit as a whole to become longer and thinner. ': [507],
#  'What is another word for long, planar igneous intrusions?': [508],
#  'The Hawaiian Islands are made up almost entirely of what?': [509],
#  'What is petrology?': [510],
#  'What do petrologists use electron microprobes in the laboratory for?': [511],
#  'How else can petrologists understand the pressures at which different mineral phases appear?': [512],
#  'What type of geologists give information about strain within the crystalline structure of the rocks?': [513],
#  'Zones in which mountains are built along convergent tectonic plate boundaries are called what?': [514],
#  'The analysis of stratigraphic sections such as drill cores is done by who?': [515],
#  'Who analyzes rock samples from drill cores in the lab? ': [516],
#  'Fielding H. Garrison believes that the science of geology can be traced to where?': [517],
#  'Who is viewed as the first modern geologist?': [518],
#  'Who produced the first geological map of the U.S.?': [519],
#  'First published by Sir Charles Lyell in 1830 this book was called what? ': [520],
#  'What word is the word pharmacy taken from?': [521],
#  'What type of professionals are pharmacists?': [522],
#  'Who oversees a Pharmacy Technician in the UK?': [523],
#  'Who was a man studying medicinal applicants of plants in Ancient Greece?': [524],
#  "How were the men who did tasks like those of today's pharmacists viewed in Japan in the Asuka and Nara periods?": [525],
#  'Developments in which scientists influenced the creation of pharmacology in medieval Islam?': [526],
#  'How far does one pharmacy in Croatia date back to?': [527],
#  'What is the dispensary subject to in a majority of countries?': [528],
#  'Where do pharmacists acquire more preparation following pharmacy school?': [529],
#  'Where are many hospital pharmacies located?': [530],
#  'What do the services given by pharmacists provide?': [531],
#  "What is one example of what a clinical pharmacist's duties entail?": [532],
#  'What type of authority are ambulatory care pharmacists given in the U.S. federal health care system?': [533],
#  'What is consultant pharmacy mainly concerned with?': [534],
#  'When did internet pharmacies begin to come into being?': [535],
#  'Why might customers order from internet pharmacies?': [536],
#  'What conditions must be met for a prescription for a controlled substance to be valid?': [537],
#  'What is a reason for the movement to legalize importing medicines from other countries?': [538],
#  'What two things does pharmacy informatics bring together?': [539],
#  'What is the fastest growing area in the pharmaceutical industry?': [540],
#  'How are pharmacists regulated in most jurisdictions?': [541],
#  'Where are some physicians permitted to prescribe and give out medications within their practices?': [542],
#  'Why is majority rule used?': [543],
#  'What will be the importance of the pharmacist in coming decades?': [544],
#  'Which provinces in Canada limit the rights of pharmacists in prescribing?': [545],
#  'What are the two symbols that signify pharmacy in English-speaking countries?': [546],
#  'What is it called when people in society rebel against laws they think are unfair?': [547],
#  'Sophocles demonstrated civil disobedience in a play that was called?': [548],
#  'After the Peterloo massacre what poet wrote The Massacre of Anarchy?': [549],
#  'Vice President Agnew describes Civil disobedience in what activities?': [550],
#  'Who wrote that it is difficult to produce an all inclusive definition of civil disobedience?': [551],
#  'If the head of government refuses to enforce a decision of the highest court what terminology could be used?': [552],
#  'What author argues pitching the conscience versus the collective?': [553],
#  'Some theories argue that civil disobedience is justified in regard to?': [554],
#  'If law breaking is not done in a public manor it is not considered what term?': [555],
#  "Cristian Bay's encyclopedia concludes that civil disobedience does not only include what behavior?": [556],
#  'What is it called when there is an active attempt to overthrow a government or belief system?': [557],
#  'When did the earliest examples of civil disobedience as a whole occur?': [558],
#  'Civil disobedients have chosen many different kinds of what type of behaviors?': [559],
#  'What was Joseph Haas arrested for?': [560],
#  'Boycotting, refusing to pay taxes, sit ins, and draft dodging all make what harder?': [561],
#  'What type of government investigations apply to civil disobedience?': [562],
#  'What do some civil disobedient people feel the need to acknowledge.': [563],
#  'What is an important personal decision for civil disobedients?': [564],
#  'Where in Las Vegas did a famous protest take place?': [565],
#  'Why do some people chose to go to jail for their disobedience?': [566],
#  'What type of punishment is sometimes offered to civil disobedients?': [567],
#  'What way do some people perform civil disobedience in a constructive way?': [568],
#  'What is the primary goal of pleading not guilty when arrested for Civil Disobedience?': [569],
#  'What needs to be avoided with civil disobedience?': [570],
#  'What is violating a law which is not the goal of the protest called?': [571],
#  'What is the main goal of criminal punishment of civil disobedients?': [572],
#  'What is the process of constructing a building or infrastructure?': [573],
#  'Who normally manages a construction job?': [574],
#  'What are the three sectors of construction?': [575],
#  'What is Engineering News-Record?': [576],
#  'What are the three construction subsectors?': [577],
#  'What is the process of adding structure to real property or construction of buildings?': [578],
#  'Residential construction practices, technologies, and resources must conform to what?': [579],
#  'New techniques of building construction are being researched, made possible by advances in what?': [580],
#  'Construction involves the translation of what?': [581],
#  'The modern trend in design is toward integration of what?': [582],
#  'What project structures assist the owner in integration?': [583],
#  'What can construction projects suffer from?': [584],
#  'Who are likely participants in creating an overall plan for the financial management of the building construction project?': [585],
#  'What must a project adhere to?': [586],
#  'What is a complex net of contracts and other legal obligations?': [587],
#  'A growing number of new forms of procurement involves what?': [588],
#  'In the most common construction procurement, who acts as the project coordinator?': [589],
#  "Who produces a list of requirements for a project, giving an overall view of the project's goals?": [590],
#  'Who is required to verify and have existing utility lines marked?': [591],
#  'What is the annual construction industry revenue in 2014?': [592],
#  'What is the average construction salary in the Middle East?': [593],
#  'What is one of the most dangerous occupations in the world?': [594],
#  'Along with non-governmental and nonstate schools, what is another name for private schools?': [595],
#  'What is the yearly cost of some notable prep schools in New England?': [596],
#  'What is another term for year 12 of education?': [597],
#  "What religion's schools does the term 'parochial schools' generally refer to?": [598],
#  'What power is available to Australian private schools but generally not present in public schools?': [599],
#  'Along with the Anglican Church and Uniting Church, what religious denomination operates private schools in Australia?': [600],
#  'What article of the Grundgesetz grants the right to make private schools?': [601],
#  "What is the German term for segregating students based on their parents' wealth?": [602],
#  'What are private secondary schools in Germany called?': [603],
#  'What is the term for an Indian private school?': [604],
#  'Along with trusts, what other non-profits are allowed to run schools in India?': [605],
#  'What is the Irish term for private schools?': [606],
#  'In what year did Malaysia receive its independence?': [607],
#  'What is a term for schools that receive government assistance?': [608],
#  'How many private schools existed in New Zealand in April 2014?': [609],
#  'What denomination is the Diocesan School for Girls in Auckland affiliated with?': [610],
#  'What percentage of Filipino primary school students are in private schools?': [611],
#  'What is the name of the scheme that provides tuition and fee assistance to students due to excess enrollment?': [612],
#  'What South African law recognized two types of schools?': [613],
#  'After apartheid, what types of schools are referred to as "Model C" schools?': [614],
#  'As of 2008, about what percentage of Swedish students attended private schools?': [615],
#  'Up to what age do students in the United Kingdom attend preparatory schools?': [616],
#  'What court case desegregated schools in the United States?': [617],
#  'Along with tuition, scholarships, vouchers, donations and grants, where does funding for private schools come from?': [618],
#  'What was the first US state to have compulsory education?': [619],
#  'About how much did a New York City day school cost annually in 2012?': [620],
#  'What individual is the school named after?': [621],
#  'What is the worlds largest academic and private library system?': [622],
#  'What is the major US city that the is the university located?': [623],
#  'In what year was the school formed?': [624],
#  'Ministers of what faith were trained by the university in early years?': [625],
#  'In what year did Harvard President Joseph Willard die?': [626],
#  "in 1846 who's natural history lectures were acclaimed in New York and Harvard?": [627],
#  'What president eliminated the Christian position in the curriculum?': [628],
#  'Who lead the school back to leading research institution in 2oth century?': [629],
#  'What was the ratio of men to women at Harvard/Radcliffe?': [630],
#  'How far from state house in downtown Boston is Harvard Yard?': [631],
#  'Where is Harvard stadium located?': [632],
#  'How much more land does the school own in Allston than Cambridge?': [633],
#  'What is the total number of professors, instructors, and lecturers at Harvard?': [634],
#  'What was the Harvard endowment total in 2011?': [635],
#  'When was the divestment from South Africa movement? ': [636],
#  'What is the applicant admission rate for class of 2019?': [637],
#  'Between 1978 an d2008 four year full time undergraduate students were required to complete how many classes outside of their concentration?': [638],
#  'What is the duration of Harvard Academic year?': [639],
#  'What is tuition for 2012 - 13 year at Harvard? ': [640],
#  'What is the center library in the Harvard library system?': [641],
#  'How many museums comprise Harvard Art Museums?': [642],
#  'Starting in what year has Harvard topped the Academic Rankings of World Universities?': [643],
#  'How many intercollegiate sports does Harvard compete in NCAA division I': [644],
#  'What was the first year that Yale and Harvard played football?': [645],
#  "What is the name of Harvard's basketball facility?": [646],
#  'Harvard - Yale Regatta predates "The Game" by how many years?': [647],
#  'What UN secretary went to Harvard?': [648],
# ...
#  'What type of arts flourished in the Yuan?': [784],
#  'Which khanates had converted to Islam?': [785],
#  'When was Zhu Shijie born?': [786],
#  'What did Guo Shoujing do for calendars?': [787],
#  'Who were otachi?': [788],
#  'How many schools of medicine were recognized in China?': [789],
#  'What was huihui?': [790],
#  'How did the Mongols acquire Chinese printing technology?': [791],
#  "What was the Yuan's paper money called?": [792],
#  "What Mongolian system did Kublai's government compromise with?": [793],
#  'Who did the Mongols bring to China as administrators?': [794],
#  'What Yuan policies did Muslims dislike?': [795],
#  "Who thought that the Yuan's social class system shouldn't be called social classes?": [796],
#  'Which part of China had people ranked higher in the class system?': [797],
#  'Who did the Mongols give control of Korea?': [798],
#  'What region of China is Hebei part of?': [799],
#  'The immune system protects organisms against what?': [800],
#  'What happens when the immune system less active than normal?': [801],
#  'Who won the Nobel Prize in 1905?': [802],
#  'What type of immune systems are found in all plants and animals?': [803],
#  'The adaptive immune system must distinguish between what types of molecules?': [804],
#  'What part of the innate immune system identifies microbes and triggers immune response?': [805],
#  'What is a mechanical barrier in insects that protects the insect?': [806],
#  'What are the anitmicrobial peptides secreted by the skin called?': [807],
#  'What serves as a biological barrier by competing for space and food in the GI tract?': [808],
#  'What is one of the first responses the immune system has to infection?': [809],
#  'What type of cells engulf or eat pathogens and foreign particles?': [810],
#  'What are two types of phagocytes that travel through the body to find invading pathogens?': [811],
#  'What are white blood cells known as?': [812],
#  'What are the phagocytes that are located in tissues in contact with the external environment called?': [813],
#  "What is one part of the innate immune system that doesn't attack microbes directly?": [814],
#  'In what types of organisms did the adaptive immune system first evolve?': [815],
#  'What are the two major subtypes of T cells?': [816],
#  'What kind of T cells kill cells that are infected with pathogens?': [817],
#  'What co-receptor recruits molecules inside the T cell that are responsible for cell activation?': [818],
#  'Gamma delta T cells share the characteristics of what other types of T cells?': [819],
#  'What kind of cell identifies pathogens when the antibodies on its surface complex with a specific foreign antigen?': [820],
#  'When B cells and T cells begin to replicate, what do some of their offspring cells become?': [821],
#  'Newborns are vulnerable to infection because they have no previous exposure to what?': [822],
#  'Hormones can alter the sensitivity of the immune system, so they can be referred to as what?': [823],
#  'What is a protein that is closely intertwined with circadian rhythms?': [824],
#  'What is partially responsible for weakened immune response in older individuals?': [825],
#  'What type of immune cells help to destroy abnormal cells in tumors?': [826],
#  'Plants lack what kind of immune cells?': [827],
#  'What kind of disorders are the result of an overactive immune response?': [828],
#  "What kind of disorders occur when part of the immune system isn't active?": [829],
#  'By what process can active immunity be generated in an artificial manner?': [830],
#  'Bacteria often secrete what kind of proteins to ingest a physical barrier?': [831],
#  'Who formulated the idea of clonal selection theory of immunity?': [832],
#  'What are the most powerful class of anti-inflammatory drugs?': [833],
#  'What are examples of differentiated effector cells that peak during wake periods?': [834],
#  'What does a T cell extend when it encounters a foreign pathogen?': [835],
#  'What are the proteins that organisms use to identify molecules associated with pathogens?': [836],
#  'What molecules of the adaptive immune system only exist in jawed vertebrates?': [837],
#  'Invertebrates do not generate what type of cells that are a part of the vertebrate adaptive immune system?': [838],
#  'What were the two main theories of immunity at the end of the 19th century?': [839],
#  "Tumors that are able to evade the body's immune response can become what?": [840],
#  "What is the name for a response of the immune system that damages the body's native tissues?": [841],
#  'What is the process by which pathogens evade the immune system by hiding inside the host cells called?': [842],
#  'What is the process by which the adaptive immune system is evaded by the chainging of non-essential epitopes called?': [843],
#  'What is the process by which the immune system identifies tumors called?': [844],
#  'At what size and larger can drugs elicit a neutralizing immune response?': [845],
#  'Drop in the blood levels of cortisol and epinephrine results in increase levels of what hormones?': [846],
#  'The immune systems of bacteria have enzymes that protect against infection by what kind of cells?': [847],
#  'Complement proteins bind to what kind of molecules on the surface of microbes in order to elicit an immune response?': [848],
#  'What organization is the IPCC a part of?': [849],
#  'Who is the chair of the IPCC?': [850],
#  'Who is on the IPCC Panel?': [851],
#  'When was the IPCC Trust Fund founded?': [852],
#  'What does the IPCC not do?': [853],
#  'How many coordinating lead authors does an IPCC report chapter have?': [854],
#  'What does the WG I Summary for Policymakers report say human activities are doing to greenhouse gases?': [855],
#  'When was the joint statement on climate change issued?': [856],
#  'Which IPCC author criticized the TAR?': [857],
#  'How does the IPCC prepare Special Reports?': [858],
#  'What other activities does the UNFCCC require the IPCC to run?': [859],
#  'What did the IPCC say was mistaken?': [860],
#  "What was Robert Watson's role in the IPCC?": [861],
#  'When was the paper published that the "Millennial Northern Hemisphere temperature reconstruction" graph was based on?': [862],
#  'What range of years was the current warming compared to?': [863],
#  'Who was the chairman of the House Committee on Energy and Commerce?': [864],
#  'When was the IPCC Fourth Assessment Report published?': [865],
#  'When was a study published confirming the 2001 IPCC projections?': [866],
#  'What danger did the IPCC understate?': [867],
#  "What role did Michael Oppenheimer have in the IPCC's reports?": [868],
#  'What has successfully dealt with ozone depletion?': [869],
#  'Who said people involved in the ozone situation had "a better understanding of scientific ignorance and uncertainties"?': [870],
#  'What does the IPCC rely on for research?': [871],
#  'How many scientists called to change the IPCC in Feb 2010?': [872],
#  'What is the only divisor besides 1 that a prime number can have?': [873],
#  'What is the name of the property that designates a number as being prime or not?': [874],
#  'How many prime numbers exist?': [875],
#  'What is the name of the supposition that any number larger than 2 can be represented as the sum of two primes?': [876],
#  ' Any even number larger than what cannot be considered prime?': [877],
#  'What number did early Greeks not regard as a true number?': [878],
#  'Which theorem would be invalid if the number 1 were considered prime?': [879],
#  'What is the name of the Egyptian papyrus that suggests that they may have had knowledge of prime numbers?': [880],
#  "In what year did Pierre de Fermat declare Fermat's little theorem?": [881],
#  'What is the most elemental way to test the primality of any integer n?': [882],
#  'How many modern types of primality tests for general numbers n are there? ': [883],
#  'What is one straightforward case of a probabilistic test?': [884],
#  'Of what form are Sophie Germain primes?': [885],
#  'What is the name of one type of computing method that is used to find prime numbers?': [886],
#  'What is name of the function used for the largest integer not greater than the number in question?': [887],
#  'What is another way to state the condition that infinitely many primes can exist only if a and q are coprime?': [888],
#  'What function is related to prime numbers?': [889],
#  'When was the Riemann hypothesis proposed?': [890],
#  'When did Landau propose his four conjectural problems?': [891],
#  'What conjecture holds that there is an infinite amount of twin primes?': [892],
#  'Besides the study of prime numbers, what general theory was considered the official example of pure mathematics?': [893],
#  "Assuming p is a prime other than 2 or 5, then, according to Fermat's theorem, what type of decimal will 1/p always be?": [894],
#  'What is one type of public key cryptography algorithm?': [895],
#  'What type of insect employs the use of prime numbers in its evolutionary strategy?': [896],
#  'What does the word prime generally suggest?': [897],
#  'What is the name of an algebraic structure in which addition, subtraction and multiplication are defined?': [898],
#  'What theorem remains valid in unique factorization domains?': [899],
#  'In what theory is the idea of a number exchanged with that of an ideal?': [900],
#  'What are the points of algebro-geometric objects?': [901],
#  'What happens to the norm when a number is multiplied by p?': [902],
#  'Which French composer wrote ametrical music using prime numbers?': [903],
#  'Where does the Rhine empty?': [904],
#  'Where does the name Rhine derive from? ': [905],
#  'What is the conventional method to measure the Rhine? ': [906],
#  'Near Chur, which direction does the Rhine turn? ': [907],
#  'The Rhine forms an inland delta into which lake?': [908],
#  'Where is the upper canal regulation of the Rhine?': [909],
#  'How many bodies of water makes up Lake Constance? ': [910],
#  'Why does the Rhine water fall into depths at the Rheinbrech?': [911],
#  'After the Rhine emerges from Lake Constance, what direction does it flow?': [912],
#  'What is the first major city in the stream of the Rhine?': [913],
#  'Which century was there a program to straighten the Rhine? ': [914],
#  'What is the longest river in Germany?': [915],
#  'What flows between the Bingen and Bonn?': [916],
#  'What contributed to water pollution in the Rhine? ': [917],
#  "Besides viniculture, what's a dominant economic sector of the Middle Rhine?": [918],
#  'What city has the biggest port in Germany?': [919],
#  'What is the Dutch name for the Rhine?': [920],
#  'If two thirds of the Rhine flows through the Maas, where doe the other one third flow through?': [921],
#  'What is the name for the smaller streams along the region northern Germany?': [922],
#  'What is the name of the Delta in the Netherlands? ': [923],
#  "At Millingen aan de Rijn where the Rhine splits, what does it change it's name to?": [924],
#  'What flood impacted the Meuse?': [925],
#  'What is the term for closing off rivers that are no longer connected?': [926],
#  'What type of Delta is the Rhine-Meuse?': [927],
#  'The present Mediterranean Sea descends from what sea?': [928],
#  'What rift system developed in the Alpine orogeny?': [929],
#  'How did the Rhine extend watershed southward? ': [930],
#  'What period was 2.5 million years ago?': [931],
#  'When did the last glacial start?': [932],
#  'What was the source of the Rhine in the last Ice Age?': [933],
#  'When did Europe slowly begin to warm up from the last Ice Age?': [934],
#  'When did tides and currents similar to our current system begin?': [935],
#  'When was the Holocene?': [936],
#  'When have humans started impacting the delta?': [937],
#  'Where do the branches Waal and Nederrijn-Lek discharge to?': [938],
#  'When was the Rhine first discovered?': [939],
#  'When did Augustus die?': [940],
#  'How many legions in five bases were along the Rhine by the Romans?': [941],
#  'When did Germanic tribes cross the Rhine to migrate?': [942],
#  'When did the Rhine become borders with Francia?': [943],
#  'What was the name of the time the Upper Rhine form a border between France and Germany?': [944],
#  'When was Rhineland subject to the Treaty of Versailles?': [945],
#  'Where is the Rhine Bridge?': [946],
#  'What was the accepted length of the Rhine prior to 1932?': [947],
#  'When was the current parliament of Scotland convened?': [948],
#  'What remained an important issue in Scottish national identity for many years?': [949],
#  'Which sea was oil discovered in?': [950],
#  'Where was an elected assembly to be set up, under the terms of the Scotland Act of 1978?': [951],
#  'In the range between 1980 and 1990, what did demand for grow?': [952],
#  'Where has the official home of the Scottish Parliament been since 2004?': [953],
#  "Where was Parliament's temporary home whilst the permanent building was being built?": [954],
#  'Who did the Parliament rent additional buildings from?': [955],
#  'Who is elected to serve as the Presiding Officer at the beginning of each parliamentary session?': [956],
#  'Who is responsible for ensuring the Parliament works smoothly?': [957],
#  'What is the seating arrangement of the debating chamber?': [958],
#  'What is the parliamentary mace made of?': [959],
#  'Which month is the first in the year Parliament takes a two week vacation?': [960],
#  'What day of the week does the Time for Reflection take place?': [961],
#  'Who decides who gets to speak in the chamber debates?': [962],
#  'What time do the MSPs normally decide on the motions and amendments from that day?': [963],
#  'What can often be predicted beforehand?': [964],
#  'When is the Members Debate held?': [965],
#  'Where is much of the work of the Scottish Parliament done?': [966],
#  'Who are committees comprised of?': [967],
#  'When are subject committees established?': [968],
#  'What is set up to scrutinize private bills submitted by party outsiders?': [969],
#  'What act sets forth the functions of the Scottish Parliament?': [970],
#  'Where are reserved matters stated in the Scotland Act?': [971],
#  'What is the name of matters outside the legislative ability of the Scottish Parliament?': [972],
#  'What may be presented to Parliament in various ways?': [973],
#  'What is stage 1 in the life of a bill?': [974],
#  'What is the final stage of a bill in the Scottish Parliament?': [975],
#  'Who does the Presiding Officer submit the final bill to?': [976],
#  'What party forms the Scottish Parliament?': [977],
#  'What day of the week are general elections held?': [978],
#  'What enables the Scottish Parliament to scrutinize the government?': [979],
#  'What is set aside for question periods in the debating chamber?': [980],
#  'What is the number of Constituency MSPs?': [981],
#  'How are the total numbers of seats allocated to parties?': [982],
#  'What does being an MSP share with the House of Commons?': [983],
#  'When the election produced an SNP majority government, what was it the first occurrence of?': [984],
#  'The loss of Edinburgh Pentlands really disappointed whom the most?': [985],
#  'What consequence of establishing the Scottish Parliament applies to Scottish MPs sitting in the UK House of Commons?': [986],
#  'What is an Islamic revival movement?': [987],
#  'What process do moderate and reformist Islamists work within the boundaries of?': [988],
#  'What exists between fundamentalist Islamism and reformist Islamism?': [989],
#  'What type of role that Islamism seeks makes it a somewhat controversial concept?': [990],
#  'What term do Islamists think should be applied to them?': [991],
#  'When did Western governments support fledgling Islamists?': [992],
#  'Who is the President of Egypt?': [993],
#  'What type of interpretation of Islam does Salafism promote?': [994],
#  'What type of movement is the Muslim Brotherhood?': [995],
#  'What was Iqbal studying in England and Germany?': [996],
#  'What did Iqbal fear would weaken the spiritual foundations of Islam and Muslim society?': [997],
#  'Who was an important figure in the twentieth-century Islamic revival in India?': [998],
#  'What did Maududi believe Muslim society could not be Islamic in the absence of?': [999],
#  ...}

# %% [markdown]
# ## Partie 2

# %%
from sentence_transformers import SentenceTransformer
import sentence_transformers.util
import numpy as np

# Example :

model = SentenceTransformer('msmarco-distilbert-base-v3')

query_embedding = model.encode('How big is London')
passage_embedding = model.encode('London has 9,787,426 inhabitants at the 2011 census')

print("Similarity:", sentence_transformers.util.pytorch_cos_sim(query_embedding, passage_embedding))

# %%
from src.model_computation import sentence_transformer_tests, k_nearest_neighbours_context, vector_search, get_embeddings_and_index

# %%
results_of_all_model = []

# %%
model = SentenceTransformer('msmarco-distilbert-base-dot-prod-v3')
result, embeddings, questions_embedding, run_time = sentence_transformer_tests(model, True, df, uniques_question, question_and_answer)

# %%
results_of_all_model.append(np.array([result, run_time], dtype=float))

# %%
model = SentenceTransformer('msmarco-roberta-base-ance-firstp')
result, embeddings, questions_embedding, run_time = sentence_transformer_tests(model, True, df, uniques_question, question_and_answer)

# %%
results_of_all_model.append(np.array([result, run_time], dtype=float))

# %%
model = SentenceTransformer('msmarco-distilbert-base-tas-b')
result, embeddings, questions_embedding, run_time = sentence_transformer_tests(model, True, df, uniques_question, question_and_answer)

# %%
results_of_all_model.append(np.array([result, run_time], dtype=float))

# %%
model = SentenceTransformer('msmarco-MiniLM-L-6-v3')
result, embeddings, questions_embedding, run_time = sentence_transformer_tests(model, False, df, uniques_question, question_and_answer)

# %%
results_of_all_model.append(np.array([result, run_time], dtype=float))

# %%
model = SentenceTransformer('msmarco-MiniLM-L-12-v3')
result, embeddings, questions_embedding, run_time = sentence_transformer_tests(model, False, df, uniques_question, question_and_answer)

# %%
results_of_all_model.append(np.array([result, run_time], dtype=float))

# %%
model = SentenceTransformer('msmarco-distilbert-base-v3')
result, embeddings, questions_embedding, run_time = sentence_transformer_tests(model, False, df, uniques_question, question_and_answer)

# %%
results_of_all_model.append(np.array([result, run_time], dtype=float))

# %%
model = SentenceTransformer('msmarco-distilbert-base-v4')
result, embeddings, questions_embedding, run_time = sentence_transformer_tests(model, False, df, uniques_question, question_and_answer)

# %%
results_of_all_model.append(np.array([result, run_time], dtype=float))

# %%
model = SentenceTransformer('msmarco-roberta-base-v3')
result, embeddings, questions_embedding, run_time = sentence_transformer_tests(model, False, df, uniques_question, question_and_answer)

# %%
results_of_all_model.append(np.array([result, run_time], dtype=float))

# %%
label = ['msmarco-distilbert-base-dot-prod-v3', 'msmarco-roberta-base-ance-firstp', 'msmarco-distilbert-base-tas-b',
         'msmarco-MiniLM-L-6-v3', 'msmarco-MiniLM-L-12-v3', 'msmarco-distilbert-base-v3',
         'msmarco-distilbert-base-v4', 'msmarco-roberta-base-v3']

# %%
import pandas as pd

indexing = ['MRR', 'Speed (in ms)']

d = {label[0]: results_of_all_model[0], 
                         label[1]: results_of_all_model[1],
                         label[2]: results_of_all_model[2],
                         label[3]: results_of_all_model[3], 
                         label[4]: results_of_all_model[4],
                         label[5]: results_of_all_model[5],
                         label[6]: results_of_all_model[6]}
df_result = pd.DataFrame(d, index=indexing)
df_result
# Out:
#                msmarco-distilbert-base-dot-prod-v3  ...  msmarco-distilbert-base-v4
# MRR                                       0.741253  ...                    0.737497
# Speed (in ms)                           629.599224  ...                  587.332030
#
# [2 rows x 7 columns]

# %%
import matplotlib.pyplot as plt

plt.plot(results_of_all_model)
plt.show()

# %% [markdown]
# After the exploration phase, we've discovered that the best model is the "msmarco-distilbert-base-tas-b". With a mean reciprocal rank of 80%.
#
# So we'll use this one for the rest of this part of the project.

# %%
model = SentenceTransformer('msmarco-distilbert-base-tas-b')

embeddings = model.encode(df.context.to_list(), show_progress_bar=True)
# Out:
# Batches:   0%|          | 0/369 [00:00<?, ?it/s]

# %%
embeddings, index = get_embeddings_and_index(embeddings, df)

# %%
# Querying the index
D, I = vector_search(uniques_question, model, index, num_results=5)

# %%
ranks = get_ranks_for_mrr(question_and_answer, uniques_question, I)
print(mean_reciprocal_rank(ranks))
# Out:
# 0.828609341825903

# %%
print(uniques_question[0])
nn = k_nearest_neighbours_context(uniques_question[0], 5, df)
# Out:
# In what country is Normandy located?
# Batches:   0%|          | 0/369 [00:00<?, ?it/s]

# %%
nn
# Out:
# ['The Normans (Norman: Nourmands; French: Normands; Latin: Normanni) were the people who in the 10th and 11th centuries gave their name to Normandy, a region in France. They were descended from Norse ("Norman" comes from "Norseman") raiders and pirates from Denmark, Iceland and Norway who, under their leader Rollo, agreed to swear fealty to King Charles III of West Francia. Through generations of assimilation and mixing with the native Frankish and Roman-Gaulish populations, their descendants would gradually merge with the Carolingian-based cultures of West Francia. The distinct cultural and ethnic identity of the Normans emerged initially in the first half of the 10th century, and it continued to evolve over the succeeding centuries.',
#  'Denmark (/ˈdɛnmɑrk/; Danish: Danmark [ˈd̥ænmɑɡ̊]) is a country in Northern Europe. The southernmost of the Nordic countries, it is located southwest of Sweden and south of Norway, and bordered to the south by Germany. Denmark forms part of the cultural region called Scandinavia, together with Sweden and Norway. The Kingdom of Denmark is a sovereign state that comprises Denmark and two autonomous constituent countries in the North Atlantic Ocean: the Faroe Islands and Greenland.',
#  'The following outline is provided as an overview, and topical guide to Denmark.Denmark – country located in Scandinavia of Northern Europe.  It is the southernmost of the Nordic countries. The mainland is bordered to the south by Germany; Denmark is southwest of Sweden and south of Norway. Denmark borders both the Baltic and the North Sea.',
#  'In the course of the 10th century, the initially destructive incursions of Norse war bands into the rivers of France evolved into more permanent encampments that included local women and personal property. The Duchy of Normandy, which began in 911 as a fiefdom, was established by the treaty of Saint-Clair-sur-Epte between King Charles III of West Francia and the famed Viking ruler Rollo, and was situated in the former Frankish kingdom of Neustria. The treaty offered Rollo and his men the French lands between the river Epte and the Atlantic coast in exchange for their protection against further Viking incursions. The area corresponded to the northern part of present-day Upper Normandy down to the river Seine, but the Duchy would eventually extend west beyond the Seine. The territory was roughly equivalent to the old province of Rouen, and reproduced the Roman administrative structure of Gallia Lugdunensis II (part of the former Gallia Lugdunensis).',
#  'England /ˈɪŋɡlənd/ is a country that is part of the United Kingdom. It shares land borders with Scotland to the north and Wales to the west. The Irish Sea lies northwest of England and the Celtic Sea lies to the southwest. England is separated from continental Europe by the North Sea to the east and the English Channel to the south.']
